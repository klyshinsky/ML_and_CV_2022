# %% [markdown]
# # Методы семантического анализа текстов

# %% [markdown]
# ## Сходство между словами
#
# You shall know a word by the company it keeps.
#
# *Frith*
#
#  Варкалось. Хливкие шорьки<br>
#    Пырялись по наве,<br>
#    И хрюкотали зелюки,<br>
#    Как мюмзики в мове.<br>
#
# *Кэррол*

# %% [markdown]
# Не очень ясно что именно могут делать *зелюки*. Но если мы узнаем кто еще может *хрюкотать*, то мы можем посчитать, что нашли слово со сходным значением или, как минимум, относящееся к одной смысловой группе.
#
# Аналогично мы не понимаем кто (что) такие *шорьки*. Если они бывают ответственными - это одно, если электронными - другое.

# %% [markdown]
# Модель описана в статье [Т.Миколова и др.](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) Идея метода основывается на оптимизации функционала, основанного на логарифмах вероятностей совместной встречаемости слов. Помимо этого, вводятся отрицательные примеры, вероятности которых не суммируются, а вычитаются. При этом отрицательных примеров берется больше, чем положительных.

# %% [markdown]
# - Возьмем текст и разделим его на слова, выделим слова со значимыми частями речи.
# - Пройдемся по всем словам текста. Возьмем несколько соседних слов справа и слева от текущего. Посчитаем частоты их совместной встречаемости.
# - Отсеем все слова, которые встречаются слишком редко или с малым количеством других слов.

# %%
import pandas as pd
import numpy as np

import pymorphy2
import re
from tqdm.auto import tqdm

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier

# %%
import re
import nltk
import nltk.data

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/edward/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
with open("data/lenta2018_summer2.txt", encoding="utf-8") as newsfile: # Файл с новостями.
    text = newsfile.read()
    div_text = text.split("=====\n")[1:]
    text_news = [(n.split('\n')[0], '\n'.join(n.split('\n')[2:])) 
                 for n in div_text]
    news = pd.DataFrame(text_news, columns = ['Header', 'News'])

# %%
news.head()
# Out:
#                                               Header  \
# 0  «Королева дерьмовых роботов» перенесла операци...
# 1                     У Су-57 нашли «тайные ноу-хау»
# 2                    Знарок лишился еще одного поста
# 3  СК заинтересовался задержанием аутиста московс...
# 4  Киевляне перекрыли проспект из-за сбитого поли...
#
#                                                 News
# 0  -----\nШведская YouTube-знаменитость Симона Ге...
# 1  -----\nПерспективный российский многофункциона...
# 2  -----\nСанкт-петербургский клуб Континентально...
# 3  -----\nСледственный комитет по Москве начал пр...
# 4  -----\nБолее 100 жителей Киева перекрыли просп...

# %% [markdown]
# Давайте поделим тексты на предложения, а предложения на слова

# %%
def text_to_sentences(text):
    sentences = []
    tokenizer = nltk.data.load('tokenizers/punkt/russian.pickle')
    raw_sentences = tokenizer.tokenize(text.strip())
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(re.sub('[^a-zA-Zа-яА-яёЁ]', ' ', raw_sentence).lower().split())
    return sentences

# %%
text_to_sentences(news['News'][11])
# Out:
# [['молиться',
#   'и',
#   'воздерживаться',
#   'от',
#   'секса',
#   'посоветовали',
#   'геям',
#   'в',
#   'гонконге',
#   'чтобы',
#   'излечить',
#   'свою',
#   'гомосексуальность'],
#  ['об', 'этом', 'сообщает', 'reuters'],
#  ['кроме',
#   'этих',
#   'способов',
#   'для',
#   'излечения',
#   'геям',
#   'необходимо',
#   'выглядеть',
#   'как',
#   'мачо',
#   'перестать',
#   'смотреть',
#   'порно',
#   'и',
#   'избегать',
#   'общества',
#   'других',
#   'мужчин'],
#  ['некоторые',
#   'геи',
#   'также',
#   'посещали',
#   'сеансы',
#   'терапии',
#   'и',
#   'молитвы',
#   'во',
#   'время',
#   'которых',
#   'как',
#   'им',
#   'сообщали',
#   'их',
#   'ориентация',
#   'станет',
#   'традиционной'],
#  ['создатели',
#   'таких',
#   'программ',
#   'реабилитации',
#   'чаще',
#   'всего',
#   'консервативные',
#   'христиане',
#   'уверены',
#   'что',
#   'гомосексуальность',
#   'осознанный',
#   'выбор',
#   'человека'],
#  ['один',
#   'из',
#   'прошедших',
#   'реабилитационный',
#   'курс',
#   'сообщил',
#   'агентству',
#   'что',
#   'после',
#   'таких',
#   'сеансов',
#   'он',
#   'потерял',
#   'вес',
#   'испытывал',
#   'проблемы',
#   'со',
#   'сном',
#   'после',
#   'чего',
#   'врач',
#   'поставил',
#   'ему',
#   'диагноз',
#   'депрессия'],
#  ['по',
#   'словам',
#   'пострадавшего',
#   'он',
#   'постоянно',
#   'испытывал',
#   'чувство',
#   'вины',
#   'и',
#   'был',
#   'на',
#   'грани',
#   'самоубийства'],
#  ['гомосексуальность',
#   'легальна',
#   'в',
#   'гонконге',
#   'уже',
#   'почти',
#   'тридцать',
#   'лет'],
#  ['однако',
#   'несмотря',
#   'на',
#   'внешне',
#   'толерантную',
#   'по',
#   'отношению',
#   'к',
#   'геям',
#   'атмосферу',
#   'и',
#   'регулярно',
#   'проходящие',
#   'гей',
#   'парады',
#   'люди',
#   'с',
#   'нетрадиционной',
#   'сексуальной',
#   'ориентацией',
#   'все',
#   'еще',
#   'испытывают',
#   'давление',
#   'со',
#   'стороны',
#   'семьи'],
#  ['их', 'заставляют', 'жениться', 'и', 'заводить', 'детей'],
#  ['кроме',
#   'того',
#   'по',
#   'закону',
#   'специального',
#   'административного',
#   'района',
#   'гей',
#   'браки',
#   'запрещены']]

# %%
news['News'][0]
# Out:
# '-----\nШведская YouTube-знаменитость Симона Герц (Simone Giertz), прославившаяся необычными изобретениями, перенесла операцию. Об этом рассказали ее представители в Twitter. Еще в конце апреля девушка сообщила подписчикам о недуге. Оказалось, что у нее в мозге обнаружили доброкачественную опухоль размером с мяч для гольфа. Блогер даже дала ей имя, назвав новообразование Брайаном.  Герц сильно переживала перед хирургическим вмешательством. В одном из предоперационных видео она говорила, что очень напугана. Однако врачи быстро удалили опухоль и спасли девушке жизнь. «Симона вышла из хирургии, и ее врачи очень довольны тем, как все прошло. Она проспала достаточно долго, чтобы сделать неуместную шутку, так что все хорошо», — говорится на ее странице в Twitter.  27-летняя изобретательница из Стокгольма прославилась несколько лет назад, показывая подписчикам свои бесполезные изобретения. Например, Герц демонстрировала самодельный будильник, к которому приделана резиновая рука, избивающая спящего человека. Кроме того, девушка создавала автоматизированную машину для наливания молока в тарелку с хлопьями. Сама Герц называет себя «королевой дерьмовых роботов», на ее канал подписаны более миллиона пользователей.\n'

# %%
all_sentences = sum([text_to_sentences(x) for x in news['News']], [])

# %%
all_sentences[0]
# Out:
# ['шведская',
#  'youtube',
#  'знаменитость',
#  'симона',
#  'герц',
#  'simone',
#  'giertz',
#  'прославившаяся',
#  'необычными',
#  'изобретениями',
#  'перенесла',
#  'операцию']

# %% [markdown]
# ## Модель Word2Vec

# %%
# Импортируем библиотеки Word2Vec
from gensim.models.word2vec import Word2Vec # Собственно модель.
from gensim.models import KeyedVectors # Семантические вектора.

# %% [markdown]
# ### Использование предобученных моделей
#
# Теперь загрузим модель, обученную разработчиками проекта <a href="http://rusvectores.org/ru/models/">RusVectores</a> для русского языка на новостях. В зависимости от того, откуда вы берете модели, они могут загружаться по-разному. Более того, модель можно обучить самому - для этого нужно просто взять много размеченных текстов.

# %%
model_w2v = KeyedVectors.load_word2vec_format('data/araneum_upos_skipgram_300_2_2018.vec.gz')

# %% [markdown]
# Теперь можно получить представление слов в новом пространстве. Имейте в виду, что в данной модели они идут с частями речи!

# %%
model_w2v['огонь_NOUN']
# Out:
# array([-2.69010e-02,  1.08851e-01,  1.13100e-03, -2.76620e-02,
#        -2.50680e-02, -4.58600e-03, -1.26100e-03, -3.79600e-03,
#        -7.53080e-02, -2.39490e-02,  2.00400e-02,  6.10330e-02,
#         7.40810e-02,  9.56330e-02, -1.11446e-01,  4.60380e-02,
#        -2.24540e-02, -2.46080e-02, -8.82250e-02, -1.53180e-02,
#        -3.66000e-04, -9.46770e-02,  1.33686e-01,  5.88400e-03,
#        -5.05470e-02,  8.13820e-02, -2.88090e-02, -7.00070e-02,
#         8.74950e-02, -8.31860e-02, -2.48210e-02, -3.82660e-02,
#         6.13210e-02, -6.45530e-02,  2.66400e-03,  8.36140e-02,
#        -3.73850e-02,  3.63260e-02, -1.20000e-04, -6.90000e-02,
#         1.49810e-02,  3.03880e-02, -2.17280e-02,  2.79400e-02,
#        -5.22550e-02,  1.96660e-02,  1.52499e-01,  7.27100e-02,
#        -2.11140e-02,  5.69930e-02, -3.07870e-02,  4.09070e-02,
#         6.49290e-02,  1.91730e-02,  2.50080e-02, -2.94090e-02,
#         6.33780e-02,  1.09028e-01,  5.66630e-02, -3.62330e-02,
#         4.96900e-02, -7.09280e-02,  2.74420e-02, -1.98650e-02,
#        -4.51340e-02, -1.50980e-02, -3.99110e-02, -7.48090e-02,
#         2.94630e-02, -4.18650e-02,  9.38820e-02, -6.96000e-03,
#         4.16040e-02, -5.73700e-03,  3.39000e-02, -6.67390e-02,
#        -2.04790e-02, -4.25040e-02,  5.67500e-03, -2.83490e-02,
#        -2.34950e-02, -1.02213e-01,  4.98750e-02,  3.86900e-02,
#        -4.36590e-02,  1.31880e-02,  1.11148e-01, -9.44720e-02,
#        -5.93430e-02, -7.77140e-02,  3.85430e-02,  9.09070e-02,
#         5.09000e-04, -3.78620e-02,  8.04500e-03,  7.43830e-02,
#        -7.35100e-03,  1.70230e-02, -5.24390e-02,  7.93950e-02,
#        -1.05930e-02,  2.68270e-02, -2.39120e-02,  3.64000e-03,
#        -1.16770e-01, -4.78740e-02, -1.94120e-02, -2.09940e-02,
#        -4.56630e-02,  9.08380e-02,  1.80280e-02, -1.00870e-02,
#        -2.26930e-02, -4.89170e-02,  7.14610e-02,  2.63810e-02,
#         8.20400e-03, -2.83280e-02, -2.98600e-03,  1.03827e-01,
#         1.20600e-03,  8.00400e-02,  2.86600e-03, -4.63270e-02,
#         1.06284e-01,  2.58980e-02, -1.51700e-03,  6.35640e-02,
#        -1.21680e-02, -1.10570e-01, -7.52900e-02,  3.05160e-02,
#        -4.66550e-02,  1.21010e-02, -1.18719e-01,  1.66450e-02,
#        -9.19320e-02, -4.12540e-02, -3.70690e-02, -3.44930e-02],
#       dtype=float32)

# %%
model_w2v.most_similar('интернет_NOUN')
# Out:
# [('интеренет_NOUN', 0.9242964386940002),
#  ('интерент_NOUN', 0.915547251701355),
#  ('интренет_NOUN', 0.9038119316101074),
#  ('интрнет_NOUN', 0.8466424942016602),
#  ('итернет_NOUN', 0.8340107202529907),
#  ('интенета_NOUN', 0.8012408018112183),
#  ('инетрнет_NOUN', 0.7921423316001892),
#  ('интерет_NOUN', 0.786211371421814),
#  ('инетернет_NOUN', 0.7794284224510193),
#  ('интернт_NOUN', 0.7663599848747253)]

# %%
model_w2v.most_similar('ученый_NOUN')
# Out:
# [('исследователь_NOUN', 0.8123084902763367),
#  ('биолог_NOUN', 0.7502084374427795),
#  ('астрофизик_NOUN', 0.7438788414001465),
#  ('ученый_ADJ', 0.7298716306686401),
#  ('нейрофизиолог_NOUN', 0.7224254608154297),
#  ('нейробиолог_NOUN', 0.7219529747962952),
#  ('климатолог_NOUN', 0.7159755825996399),
#  ('зоолог_NOUN', 0.7055575251579285),
#  ('астроном_NOUN', 0.700603723526001),
#  ('палеонтолог_NOUN', 0.6994453072547913)]

# %% [markdown]
# В пространстве Word2Vec возможны векторные операции. Попробуем их.

# %%
#model_w2v.most_similar(positive=[u'пожар_NOUN'])
#model_w2v.most_similar(positive=[u'пожар_NOUN'], negative=[u'пламя_NOUN' ])
#model_w2v.most_similar(positive=[u'топливо_NOUN', u'молоко_NOUN'], negative=[u'нефть_NOUN' ])
#model_w2v.most_similar(positive=[u'женщина_NOUN', u'император_NOUN' ], negative=[u'мужчина_NOUN'])
model_w2v.most_similar(positive=[u'король_NOUN', u'женщина_NOUN'], negative=[u'мужчина_NOUN'])
#model_w2v.most_similar(positive=[u'президент_NOUN', u'женщина_NOUN'], negative=[u'мужчина_NOUN'])
# model_w2v.most_similar(negative=[u'король_NOUN', u'мужчина_NOUN'], positive=[u'женщина_NOUN'])
# model_w2v.most_similar(positive=[u'король_NOUN', u'мужчина_NOUN'], negative=[u'женщина_NOUN'])
#model_w2v.most_similar(positive=[u'женщина_NOUN', u'король_NOUN' ])
#model_w2v.most_similar(positive=[u'берлин_PROPN', u'москва_PROPN' ], negative=[u'германия_PROPN'])
# Out:
# [('королева_NOUN', 0.7022064924240112),
#  ('герцог_NOUN', 0.6763379573822021),
#  ('монарх_NOUN', 0.6703873872756958),
#  ('генрих_PROPN', 0.656510055065155),
#  ('людовик_PROPN', 0.6564112901687622),
#  ('франция::людовик_PROPN', 0.6421706080436707),
#  ('принц_NOUN', 0.640705943107605),
#  ('королевство_NOUN', 0.6257355809211731),
#  ('наследный_ADJ', 0.6177536845207214),
#  ('герцогиня_NOUN', 0.617081344127655)]

# %% [markdown]
# Можно найти лишнее слово в последовательности.

# %%
model_w2v.doesnt_match(['лук_NOUN', 'перец_NOUN', 'ученик_NOUN', 'плодовый_ADJF'])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'ученик_NOUN'

# %% [markdown]
# Итак, вместо самих слов мы можем использовать их векторные представления в некотором семантическом пространстве.
#
# <img src="img/cartoon-espresso-word2vec.jpg">

# %% [markdown]
# Беда Word2Vec состоит в том, что он генерирует только один вектор на каждое слово. То есть он не различает различных смыслов одного слова.
#
# <img src="img/cartoon-citizen-data-scientist.jpg">

# %% [markdown]
# В полученном пространстве работают векторные операции. Если обучиться на достаточно большом количестве текстов, можно получить следующие эффекты.
#
# ![](img/w2v_vect.png)
#
# ![](img/w2v_vect2.png)

# %% [markdown]
# На хорошо обученной модели можно даже превратить индекс в город и наоборот при помощи векторных операций.

# %% [markdown]
# Давайте посмотрим на реальное расположение слов в этом пространстве. Для этого нам потребуется UMAP, а то как еще мы преобразуем 300-мерное пространство в плоскость?

# %%
from umap import UMAP
from copy import copy

# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16, 12)

# %%
trees = pd.read_csv("data/trees.txt", sep='\t', names=['trees'])
herbs = pd.read_csv("data/herbs.txt", sep='\t', names=['herbs'])
trees = trees['trees'].str.lower().unique()
herbs = herbs['herbs'].str.lower().unique()

# %%
men_avg, women_avg = np.zeros(model_w2v.vector_size), np.zeros(model_w2v.vector_size)
men_count, women_count = 0, 0
men_vect, women_vect, animal_type, animal_no = [], [], [], []
dif_vect = []
names = []
men_names, women_names = [], []

for m in trees:
    if m.strip().lower()+'_NOUN' in model_w2v.vocab.keys():
        mv = model_w2v[m.strip().lower()+'_NOUN']
        men_avg += mv
        men_count += 1
        men_vect.append(mv)
        men_names.append(m)
        animal_type.append(1)
        
for w in herbs:
    if w.strip().lower()+'_NOUN' in model_w2v.vocab.keys():
        wv = model_w2v[w.strip().lower()+'_NOUN']
        women_avg += wv
        women_count += 1
        women_vect.append(wv)
        women_names.append(w)
        animal_type.append(0)

        
for i in range(men_count):
    mv = men_vect[i]
    animal_no.append(i)
    for j in range(women_count):
        wv = women_vect[j]
        dif_vect.append(mv - wv)
        names.append([men_names[i], women_names[j]])

men_avg /= men_count
women_avg /= women_count

dif_avg = men_avg - women_avg
cosines = KeyedVectors.cosine_similarities(dif_avg, dif_vect)

#print(list(zip(names, cosines)))
print([(n, c) for n, c in list(zip(names, cosines)) if c>0.6])
# Out:
# [(['клен', 'маргаритка'], 0.6117089698392721), (['клен', 'настурция'], 0.6115848257569042), (['клен', 'дельфиниум'], 0.6010003968890965), (['черешня', 'щавель'], 0.6182821208457462), (['черешня', 'редис'], 0.6446437627648164), (['самшит', 'настурция'], 0.6133552135715983), (['сосна', 'настурция'], 0.6001034566353993)]
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:902: RuntimeWarning: invalid value encountered in true_divide
#   similarities = dot_products / (norm * all_norms)

# %%
all_vect, all_names = copy(men_vect), copy(men_names)
all_vect.extend(women_vect)
all_names.extend(women_names)

umaped_vct=UMAP().fit_transform(all_vect)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], c=animal_type, s=3)

for word in ['фрукт', 'овощ', 'ягода', 'приправа', 'пряность', 'дерево', 'трава', 'цветок', 'куст']:
    ind = all_names.index(word)
    ax.scatter(umaped_vct[ind, 0], umaped_vct[ind, 1], c='r', s=7)

for n, v in zip(all_names, umaped_vct):
    ax.annotate(n, (v[0], v[1]))

plt.show()

# %% [markdown]
# А теперь давайте добавим ещё одно измерение и посмотрим, как точки будут меняться вдоль него.

# %%
from ipywidgets import interact, FloatSlider

# %%
all_vect, all_names = copy(men_vect), copy(men_names)
all_vect.extend(women_vect)
all_names.extend(women_names)

umaped_vct=UMAP(n_components=3).fit_transform(all_vect)

# %%
def drawHerbs(val):
    fig, ax = plt.subplots()
    fig.set_size_inches(15,10)
    temp_data = np.array([u for u in umaped_vct if u[2]>=val-0.5 and u[2]<=val+0.5])
    temp_names = [all_names[i] for i, u in enumerate(umaped_vct) if u[2]>=val-0.5 and u[2]<=val+0.5]
    
    ax.scatter(temp_data[:, 0], temp_data[:, 1], c=temp_data[:, 2], s=30)

    for word in ['фрукт', 'овощ', 'ягода', 'приправа', 'пряность', 'дерево', 'трава', 'цветок', 'куст']:
        ind = all_names.index(word)
        ax.scatter(umaped_vct[ind, 0], umaped_vct[ind, 1], c='r', s=7)
        ax.annotate(word, (umaped_vct[ind, 0], umaped_vct[ind, 1]))

    for n, v in zip(temp_names, temp_data):
        ax.annotate(n, (v[0], v[1]))

    plt.show()

# %%
sld1 = FloatSlider(value=(min(umaped_vct[:, 2])+max(umaped_vct[:, 2]))/2, min=min(umaped_vct[:, 2]), max=max(umaped_vct[:, 2]), step=0.1, description='Filter by Z')

interact(drawHerbs, val=sld1);
# Out:
# interactive(children=(FloatSlider(value=7.568556308746338, description='Filter by Z', max=8.863116264343262, m…

# %% [markdown]
# ### Обучение собственной модели в Word2Vec

# %%
# %%time

# список параметров, которые можно менять по вашему желанию
num_features = 300  # итоговая размерность вектора каждого слова
min_word_count = 5  # минимальная частотность слова, чтобы оно попало в модель
num_workers = 3     # количество ядер вашего процессора, чтоб запустить обучение в несколько потоков
context = 10        # размер окна 
downsampling = 1e-3 # внутренняя метрика модели

model_our_news = Word2Vec(all_sentences, workers=num_workers, size=num_features,
                 min_count=min_word_count, window=context, sample=downsampling)
# Out:
# CPU times: user 38.9 s, sys: 203 ms, total: 39.1 s
# Wall time: 17.5 s

# %% [markdown]
# Возьмем по тысяче научных текстов из пяти разных областей науки. (Они занимают 140 Мб и не влезают на Гит, так что доступны по запросу.)

# %%
sci_texts = pd.read_csv("data/kaggle-science-texts_train.tsv", header=0, sep = ';')

# %% [markdown]
# Исходно, код выше выполнялся 37 минут. Но если поставить<br>
# `pip install pymorphy2[fast]`<br>
# то библиотека начинает работать горазо быстрее.
#
# Если морфология работает медленно, но в тексте вссегда есть повторяющиеся слова (помните закон Ципфа?), то может быть результаты медленной морфологии надо кешировать в быстром словаре (dict)?

# %%
# Список значимых частей речи. 
# Они нам потом понадобятся в немного другом виде. Так что сделаем словарь. чтобы два раза не вставать.
conv_pos = {'ADJF':'ADJ', 'ADJS':'ADJ', 'ADV':'ADV', 'NOUN':'NOUN', 
            'VERB':'VERB', 'PRTF':'ADJ', 'PRTS':'ADJ', 'GRND':'VERB'}

tmp_dict = {} # Кеш значимых слов.
nones = {} # Кеш незначимых слов.

morph = pymorphy2.MorphAnalyzer()

# Фильтруем по части речи и возвращаем только начальную форму.
def normalizePymorphy(text, need_pos=True):
    tokens = re.findall('[A-Za-zА-Яа-яЁё]+\-[A-Za-zА-Яа-яЁё]+|[A-Za-zА-Яа-яЁё]+', text)
    words = []
    for t in tokens:
        # Если токен уже был закеширован, быстро возьмем результат из него.
        if t in tmp_dict.keys():
            words.append(tmp_dict[t])
        # Аналогично, если он в кеше незначимых слов.
        elif t in nones.keys():
            pass
        # Слово еще не встретилось, будем проводить медленный морфологический анализ.
        else:
            pv = morph.parse(t)
            if pv[0].tag.POS != None:
                if pv[0].tag.POS in conv_pos.keys():
                    if need_pos:
                        word = pv[0].normal_form+"_"+conv_pos[pv[0].tag.POS]
                    else:
                        word = pv[0].normal_form
                    # Отправляем слово в результат, ...
                    words.append(word)
                    # ... и кешируем результат его разбора.
                    tmp_dict[t] = word
                else:
                    # Для незначимых слов можно даже ничего не хранить. Лишь бы потом не обращаться к морфологии.
                    nones[t] = ""
                    
    return words

# %%
# %%time
sci_texts['NText'] = sci_texts['Text'].map(lambda x:' '.join(normalizePymorphy(x)))
# Out:
# CPU times: user 58.2 s, sys: 247 ms, total: 58.4 s
# Wall time: 58.6 s

# %%
classes = np.ones(5000)
classes[1000:2000] = 2
classes[2000:3000] = 3
classes[3000:4000] = 4
classes[4000:] = 5

# %%
# %%time
# Считаем матрицу термин-документ, но не с частотами, а со значениями Tf*Idf
X = TfidfVectorizer().fit_transform(sci_texts['NText'])
# Проводим SVD-разложение по 20 компонентам.
# Out:
# CPU times: user 8.28 s, sys: 76 ms, total: 8.36 s
# Wall time: 8.36 s

# %%
X_train, X_test, y_train, y_test = train_test_split(X, classes, test_size=0.2, random_state=333)
tree = RandomForestClassifier(criterion='entropy', random_state=333)
tree.fit(X_train, y_train)
y_hat = tree.predict(X_test)
print(len([1 for i, j in zip(y_hat, y_test) if i==j])/len(y_test))
confusion_matrix(y_test, y_hat)
# Out:
# /home/edward/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.92
# array([[203,   2,   3,   0,   1],
#        [  7, 160,  19,   4,   0],
#        [  3,   3, 198,   1,   1],
#        [  3,   2,   1, 175,  12],
#        [  1,   0,   1,  16, 184]])

# %%
sci_sentences = []
for text in tqdm(sci_texts.Text):
#     sci_sentences.extend(normalizePymorphy(text))
    sci_sentences.append(normalizePymorphy(text))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5000.0), HTML(value='')))

# %%
# %%time

# список параметров, которые можно менять по вашему желанию
num_features = 50  # итоговая размерность вектора каждого слова
min_word_count = 5  # минимальная частотность слова, чтобы оно попало в модель
num_workers = 4     # количество ядер вашего процессора, чтоб запустить обучение в несколько потоков
context = 10        # размер окна 
downsampling = 1e-3 # внутренняя метрика модели

model_our_sci = Word2Vec(sci_sentences, workers=num_workers, size=num_features,
                 min_count=min_word_count, window=context, sample=downsampling)
# Out:
# CPU times: user 2min 3s, sys: 316 ms, total: 2min 4s
# Wall time: 39.7 s

# %%
# Финализируем нашу модель. Ее нельзя будет доучить теперь, но она начнет занимать гораздо меньше места
model_our_sci.init_sims(replace=True)

# %%
# Посмотрим на самые похожие слова.
model_our_sci.most_similar('продукт_NOUN'), model_our_sci.most_similar('система_NOUN')
# Out:
# /home/edward/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# ([('продукция_NOUN', 0.6047976016998291),
#   ('жир_NOUN', 0.581264853477478),
#   ('биопродукт_NOUN', 0.5631732940673828),
#   ('концентрат_NOUN', 0.5581938624382019),
#   ('творог_NOUN', 0.5558304786682129),
#   ('медиаконтент_NOUN', 0.55180424451828),
#   ('окара_NOUN', 0.551041841506958),
#   ('медиапродукт_NOUN', 0.5493413805961609),
#   ('поликапроамид_NOUN', 0.5466698408126831),
#   ('добавка_NOUN', 0.5380804538726807)],
#  [('подсистема_NOUN', 0.779728353023529),
#   ('взаимосвязанный_ADJ', 0.6738574504852295),
#   ('непрерывный_ADJ', 0.6581292152404785),
#   ('целостность_NOUN', 0.6214752793312073),
#   ('структура_NOUN', 0.609674334526062),
#   ('принцип_NOUN', 0.6091493368148804),
#   ('взаимозависимый_ADJ', 0.6073068380355835),
#   ('пространство_NOUN', 0.6050693392753601),
#   ('интегрировать_ADJ', 0.6025133728981018),
#   ('единый_ADJ', 0.593147873878479)])

# %%
model_our_sci.most_similar('говорить_VERB')
# Out:
# /home/edward/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('видеть_VERB', 0.8318532705307007),
#  ('казаться_VERB', 0.7819486856460571),
#  ('понимать_VERB', 0.7562056183815002),
#  ('знать_VERB', 0.7414604425430298),
#  ('пытаться_VERB', 0.7404069900512695),
#  ('таков_ADJ', 0.7346587777137756),
#  ('хотеть_VERB', 0.723237931728363),
#  ('отказываться_VERB', 0.7212791442871094),
#  ('обвинять_VERB', 0.7183642387390137),
#  ('осознавать_VERB', 0.7091450095176697)]

# %%
model_our_sci.most_similar('ученик_NOUN')
# Out:
# /home/edward/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('учитель_NOUN', 0.8039760589599609),
#  ('воспитатель_NOUN', 0.7563371658325195),
#  ('учить_VERB', 0.7533738613128662),
#  ('ребята_NOUN', 0.7478272318840027),
#  ('педагог_NOUN', 0.7298271656036377),
#  ('наставник_NOUN', 0.7296416759490967),
#  ('мастерская_NOUN', 0.726949155330658),
#  ('родитель_NOUN', 0.7254551649093628),
#  ('учиться_ADJ', 0.7055633068084717),
#  ('учиться_VERB', 0.6881254315376282)]

# %%
model_our_sci.wv.most_similar('орех_NOUN')
# Out:
# [('грецкий_ADJ', 0.8999398946762085),
#  ('перец_NOUN', 0.8855680227279663),
#  ('стевий_NOUN', 0.8821319937705994),
#  ('тыква_NOUN', 0.878010094165802),
#  ('репчатый_ADJ', 0.8773719668388367),
#  ('лук_NOUN', 0.8758541941642761),
#  ('морковь_NOUN', 0.8750035166740417),
#  ('молотый_ADJ', 0.8728653192520142),
#  ('баклажан_NOUN', 0.8702030777931213),
#  ('фасоль_NOUN', 0.8693549633026123)]

# %% [markdown]
# Можно найти лишнее слово в последовательности.

# %%
# Размер проанализированного корпуса
model_our_sci.corpus_total_words
# Out:
# 7354828

# %% [markdown]
# Теперь вернемся к размеру векторов.

# %%
model_our_sci.vector_size
# Out:
# 50

# %% [markdown]
# Посмотрим как будут отображаться растения на новой модели.

# %%
men_avg, women_avg = np.zeros(model_our_sci.vector_size), np.zeros(model_our_sci.vector_size)
men_count, women_count = 0, 0
men_vect, women_vect, animal_type, animal_no = [], [], [], []
dif_vect = []
names = []
men_names, women_names = [], []

for m in trees:
    try:
        mv = model_our_sci[m.strip().lower()+'_NOUN']
        men_avg += mv
        men_count += 1
        men_vect.append(mv)
        men_names.append(m)
        animal_type.append(1)
    except:
        pass
        
for w in herbs:
    try:
        wv = model_our_sci[w.strip().lower()+'_NOUN']
        women_avg += wv
        women_count += 1
        women_vect.append(wv)
        women_names.append(w)
        animal_type.append(0)
    except:
        pass
        
for i in range(men_count):
    mv = men_vect[i]
    animal_no.append(i)
    for j in range(women_count):
        wv = women_vect[j]
        dif_vect.append(mv - wv)
        names.append([men_names[i], women_names[j]])

men_avg /= men_count
women_avg /= women_count

dif_avg = men_avg - women_avg
cosines = KeyedVectors.cosine_similarities(dif_avg, dif_vect)

#print(list(zip(names, cosines)))
print([(n, c) for n, c in list(zip(names, cosines)) if abs(c)<0.001])
# Out:
# [(['фрукт', 'корица'], 0.0006791213380006754), (['овощ', 'капуста'], 0.00030829183759333885), (['вишня', 'арбуз'], 0.00014839952430027964), (['персик', 'брусника'], 0.000900594805560725), (['бук', 'конопля'], 0.00012024818318951612), (['бук', 'нарцисс'], -0.0009409745820715739), (['шиповник', 'бамбук'], -0.0001690258837427877), (['ананас', 'чеснок'], 0.0006365034178989863)]
# /home/edward/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# /home/edward/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:902: RuntimeWarning: invalid value encountered in true_divide
#   similarities = dot_products / (norm * all_norms)

# %%
all_vect, all_names = copy(men_vect), copy(men_names)
all_vect.extend(women_vect)
all_names.extend(women_names)

umaped_vct=UMAP().fit_transform(all_vect)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], c=animal_type, s=3)

for word in ['фрукт', 'овощ', 'ягода', 'приправа', 'пряность', 'дерево', 'трава', 'цветок', 'куст']:
    ind = all_names.index(word)
    ax.scatter(umaped_vct[ind, 0], umaped_vct[ind, 1], c='r', s=7)

for n, v in zip(all_names, umaped_vct):
    ax.annotate(n, (v[0], v[1]))

plt.show()

# %% [markdown]
# ----

# %% [markdown]
# Теперь посмотрим какова размерность векторов, хранимых в модели, и сколько в ней слов.<br>
# Размерность векторов 300 - с запасом. Почти 250 000 слов - тоже очень хорошо.

# %%
print(model_w2v.vector_size)
print(len(model_w2v.index2word))
# Out:
# 300
# 196620

# %%
model_w2v.index2word[:50]
# Out:
# ['год_NOUN',
#  'мочь_VERB',
#  'человек_NOUN',
#  'время_NOUN',
#  'работа_NOUN',
#  'новый_ADJ',
#  'становиться_VERB',
#  'также_ADV',
#  'очень_ADV',
#  'день_NOUN',
#  'первый_ADJ',
#  'компания_NOUN',
#  'являться_VERB',
#  'ребенок_NOUN',
#  'иметь_VERB',
#  'система_NOUN',
#  'место_NOUN',
#  'получать_VERB',
#  'большой_ADJ',
#  'жизнь_NOUN',
#  'вопрос_NOUN',
#  'хороший_ADJ',
#  'должный_ADJ',
#  'вид_NOUN',
#  'город_NOUN',
#  'сайт_NOUN',
#  'случай_NOUN',
#  'дело_NOUN',
#  'дом_NOUN',
#  'сделать_VERB',
#  'давать_VERB',
#  'говорить_VERB',
#  'россия_PROPN',
#  'возможность_NOUN',
#  'высокий_ADJ',
#  'страна_NOUN',
#  'область_NOUN',
#  'мир_NOUN',
#  'работать_VERB',
#  'данный_ADJ',
#  'начинать_VERB',
#  'часть_NOUN',
#  'качество_NOUN',
#  'знать_VERB',
#  'сказать_VERB',
#  'позволять_VERB',
#  'хорошо_ADV',
#  'хотеть_VERB',
#  'нужно_ADV',
#  'принимать_VERB']

# %% [markdown]
# У нас есть смысл отдельных слов. Построим на его основе смысл текста как среднее арифметическое всех векторов для слов, составляющих данный текст.

# %%
index2word_set = set(model_w2v.index2word)

def text_to_vec(text):
    text_vec = np.zeros((model_w2v.vector_size,), dtype="float32")
    n_words = 0

    for word in normalizePymorphy(text):
        if word in index2word_set:
            n_words = n_words + 1
            text_vec = np.add(text_vec, model_w2v[word]) 
    
    if n_words != 0:
        text_vec /= n_words
    return text_vec

# %% [markdown]
# Рассчитаем вектора всех текстов - они нам еще пригодятся.

# %%
w2v_vectors = [text_to_vec(text) for text in news.News]

# %% [markdown]
# Найдем текст, самый похожий на некоторый текст.

# %%
vpos = 75
v1 = text_to_vec(news.News[vpos])

ms = np.argmin([np.linalg.norm(v1-w2v_vectors[i]) for i in range(news.News.shape[0]) if i!=vpos])
print(vpos, news.News[vpos])
if ms>vpos:
    print(ms+1, news.News[ms+1])
else:
    print(ms, news.News[ms])
# Out:
# 7479 -----
# Закаменский районный суд Бурятии приговорил трех полицейских к пяти годам колонии каждого по делу о пытках задержанных. Об этом «Медиазоне» сообщил юрист «Зоны права» Роман Сукачев, который представляет интересы потерпевших. Суд признал виновными начальника отделения уголовного розыска ОМВД по Закаменскому району Эрдэма Хажитова и двух оперативников — Владимира Базарсадаева и Давида Абрамова — в превышении должностных полномочий с применением насилия и спецсредств. После оглашения приговора их взяли под стражу в зале суда. Прокуратура просила приговорить полицейских к семи годам каждого. По версии следствия, в ночь на 24 сентября 2016 года Николай Баландин и Дмитрий Рабжаев зашли на территорию местного предприятия, торгующего кедровыми орехами. Заперли сторожа Евгения Баландина (он приходился Баландину родным братом) в каптерке, отобрав у него мобильный телефон и повредив стационарный. Затем взломали дверь склада и вывезли на грузовике почти три тонны орехов на полмиллиона рублей. Наутро сторож освободился и вызвал полицию. Его доставили в отдел, где, как утверждают полицейские, он сдал Баландина и Рабжаева. Через сутки сторож покончил с собой, не оставив предсмертной записки.  Адвокаты считают, что его свидетельские показания были получены под пытками. Тем не менее на их основании были задержаны Баландин и Рабжаев. Как установило следствие, их подкидывали к потолку. «В кабинете к нему [Баландину] подошел оперуполномоченный Базарсадаев, здоровяк ростом метр девяносто, весом более ста килограммов. Спросил моего подзащитного, сколько он весит. А он весит-то килограмм пятьдесят. Тогда опер поднял его за подмышки на высоту, примерно, полтора метра и бросил спиной на пол», — рассказывал «Ленте.ру» Роман Сукачев. По его словам, так Баландина бросали несколько раз, при этом сотрудники «заботливо» советовали ему не подставлять руки во избежание переломов. Полицейские надевали задержанным на голову пакет, перекрывая доступ воздуха. Одновременно с этим их били в грудь и по голове ногами и кулаками, душили, пытали электрошокером, требуя признания в краже. В итоге потерпевшие не выдержали пыток и подписали признание. Их увезли в больницу после пыток в полиции. После самоубийства сторожа осиротела его 12-летняя дочь, чьим воспитанием теперь занимается ее дядя — Николай Баландин. Летом 2017 года его вместе с Рабжаевым осудили за кражу орехов на условный срок.
#
# 7480 -----
# Бывший мэр Ярославля Евгений Урлашов, отбывающий наказание за получение взятки, рассказал журналистам о пытках в колониях. Фрагменты его письма опубликовал местный сайт 76.ru. В своем письме Урлашов утверждает, что пытки регулярно практикуются «во всех лагерях и СИЗО Ярославской области, а также по всей России». В качестве примера он приводит ситуации в рыбинском СИЗО-2 «Софийка», а также в исправительных колониях № 2 и 12 «Шексна». «Бьют жестко дубинками, кулаками, ногами. Заставляют сидеть на корточках по 4–8 часов вне зависимости от возраста и состояния здоровья. Об этом хорошо известно не только зэкам, но и многим общественным организациям, прокуратуре, Следственному комитету, различным полномочным представителям и депутатам», — пишет бывший мэр. По его словам, еще с 2016 года в ярославском СИЗО №1 «Коровники» существуют пресс-хаты по пыткам, где у подследственных выбивают показания и заставляют подписывать признания. Причем, как утверждает Урлашов, людей там не просто бьют, но еще и насилуют. Издевательства над арестованными любят снимать на видео и коллекционировать, чтобы потом «наслаждаться этими записями и понтить друг перед другом. Управление ФСИН по Ярославской области оказалось в центре скандала после публикации видео, на котором сотрудники ярославской колонии пытают заключенного. На видео более 10 человек в форме долго и методично бьют по ногам лежащего на столе посередине комнаты мужчину, закованного в наручники, поливают его голову водой из ведра. Следственный комитет возбудил дело о превышении должностных полномочий. Были задержаны 12 подозреваемых, 17 сотрудников колонии отстранены от работы. Инцидент произошел летом прошлого года, заключенного зовут Евгений Макаров. Предполагаемой причиной пытки стало неуважительное отношение к одному из сотрудников учреждения со стороны потерпевшего. Бывший мэр Ярославля Евгений Урлашов был осужден в августе 2016 года, суд признал его виновным в получении взятки и приговорил к 12,5 годам колонии. Позже срок был сокращен до девяти лет.

# %% [markdown]
# Теперь посмотрим как разспределятся тексты в новом пространстве.

# %%
umap_news = UMAP()
umaped_vct = umap_news.fit_transform(w2v_vectors)

# %%
fig, ax = plt.subplots()
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], edgecolor='b', s=3)
plt.show()

# %%
from sklearn.cluster import DBSCAN
import seaborn as sns
from matplotlib.colors import ListedColormap
from numpy.random import choice

# %% [markdown]
# Посмотрим что будет, если обучить на данных после преобразования пространства.

# %%
db=DBSCAN(eps=0.12, min_samples=3)
db_clusters=db.fit_predict(umaped_vct)
myclr=ListedColormap(choice(list(sns.xkcd_rgb.values()), max(db_clusters)+1)) # Генерируем контрастную карту цветов.
print(max(db_clusters))
fig, ax = plt.subplots()
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], s=3, c=db_clusters, cmap=myclr)
plt.show()
# Out:
# 92

# %%
clusters=list(set(db_clusters))

for c in clusters:
    print(c)
    cntr=0
    for i, a in enumerate(news.Header):
        if db_clusters[i]==c:
            print(a)
            cntr+=1
            if cntr==3:
                break
# Out:
# 0
# «Королева дерьмовых роботов» перенесла операцию на мозге
# СК заинтересовался задержанием аутиста московскими полицейскими
# Киевляне перекрыли проспект из-за сбитого полицейскими ребенка-велосипедиста
# 1
# У Су-57 нашли «тайные ноу-хау»
# Донецкие «Чебурашки» отомстили за гибель командира ополчения Мамая
# «Центр Хруничева» усохнет
# 2
# Знарок лишился еще одного поста
# Уткин обозвал Черчесова медной статуей
# Капитана «Реала» завалили угрозами за травму Салаха
# 3
# Российская легкоатлетка одержала 40 побед подряд
# Серена Уильямс попала на Шарапову
# 21-летняя россиянка обыграла вторую ракетку мира на «Ролан Гаррос»
# 4
# Британка скатилась с горы и осталась жива
# Шестилетний мальчик спас от смерти более тысячи собак
# Львы, тигры, ягуар и медведь устроили побег из немецкого зоопарка
# 5
# Нидерланды задумались привлечь Киев к ответственности за крушение «Боинга»
# Поляки спустя восемь лет обнаружили следы взрывчатки на Ту-154 Качиньского
# Нидерланды сняли с Украины ответственность за гибель MH17 в Донбассе
# 6
# Выявлен новый способ продления жизни
# Доказана эффективность вакцины против рака мозга
# Ученые обнаружили дешевый способ борьбы с раком
# 7
# ЦРУ занялось поиском говорящих на русском специалистов и ошиблось в родном языке
# Умер лауреат Нобелевской премии по медицине
# В Крыму восприняли «без слез» отказ Лаймы Вайкуле приезжать с концертами
# 8
# Авиалайнер совершил вынужденную посадку из-за невыносимо вонючего пассажира
# Блогер Сергей Доля раскрыл подробности крушения российского самолета
# Женщина-пилот посадила самолет на шоссе в час пик и попала на видео
# 9
# Названы специалисты с самыми большими в России зарплатами
# Названы самые коррумпированные сферы в России
# Россиянам предложат «почтовую» ипотеку
# 10
# Британец заглянул под кровать и испытал радость отцовства
# Хирург тайно вырезал британке орган и довел ее до самоубийства
# Американский подросток сходил в тренажерный зал и чуть не умер
# 11
# В Канаде повадились угонять гоночные ванны
# Ставившие химические опыты в иркутском ТЦ дети получили ожоги
# Россию завалило первым летним снегом
# 12
# Украина решила шантажировать Россию ценами на транзит газа
# Имущество «Газпрома» арестовано из-за Украины
# «Газпром» признал проблемы с арестом имущества
# 13
# Российскую олимпийскую чемпионку отказались пускать на Украину
# Олимпийский чемпион прокомментировал информацию о романе с Медведевой
# Украинский теннисист захотел задушить всех русских
# 14
# США поторопят Германию с размещением своих ракет
# СБУ раскрыла поставки в Россию сплавов для «Буков» и «Панцирей»
# Порошенко освободил оборонные предприятия Украины от долгов перед Россией
# 15
# Германия отбила новую попытку заблокировать «Северный поток-2»
# США накажут европейский бизнес за «Северный поток-2»
# «Газпром» даст строителям «Турецкого потока» миллиарды евро
# 16
# Опровергнута популярная гипотеза о Вселенной
# У воды нашли неожиданные аномальные свойства
# Тысячи англичан с радостью разорились на билетах в Россию
# Бывший капитан сборной Украины «попался» на отдыхе в Крыму
# На стадионе чемпионата мира отключили электричество за долги
# 78
# Депутаты подумали об имуществе россиян после их смерти
# Развод Петросяна со Степаненко предали огласке
# Развод Петросяна со Степаненко поверг россиян в шок
# 79
# Умер модельер Бенеттон
# Умер самый известный продавец 2014 года
# Nike уличили в сговоре с полицией для борьбы с поддельными кроссовками
# 80
# В Подмосковье обнаружили редкую хищную птицу
# Российские медведи станут стратегическим ресурсом
# Пляжных волейболистов посчитали причиной гибели птиц в США
# 81
# Чешские футболисты трижды попали в каркас ворот и не забили
# 19-летний футболист отличился «волшебным» ударом
# Команда побежала отмечать гол и пропустила в пустые ворота
# 82
# Назван самый высокооплачиваемый актер на планете
# Названы самые богатые музыканты
# Названы самые богатые российские знаменитости
# 83
# ФСБ выявила утечку секретных разработок из «Роскосмоса»
# Появились подробности найденной ФСБ утечки секретов из «Роскосмоса»
# Глава подразделения «Роскосмоса» уволился после обысков по делу о госизмене
# 84
# Россия осталась без одной из бед
# Российско-британский вуз в Москве лишили аккредитации
# Молодые дипломаты отметят юбилей евразийского форума
# 85
# Австралийка четверть века не смывала тушь с глаз и заработала наросты
# Американка исправила изуродованный хирургом нос пиявками
# Старушка накрасилась просроченной тушью и ослепла
# 86
# В России поспорили о значимости водки для туризма
# Стыдливая просьба убедила Путина подумать о продаже пива на стадионах
# Приезд Путина на свадьбу в Австрию попытались связать с политикой
# 87
# Более 3 тысяч видеообращений к Андрею Воробьеву записали жители Подмосковья
# Военные вывезли с норильского аэродрома 220 тонн металлолома
# Воробьев заявил о важности работы с молодежью
# 88
# Раскрыта ценность утечки о российских гиперзвуковых технологиях
# Арестованного по делу о госизмене ученого заподозрили в сливе данных о подлодках
# Сын обвиненного в госизмене ученого из «Роскосмоса» рассказал о работе отца
# 89
# В Подмосковье выставили на продажу особняк с бункером на случай апокалипсиса
# Кутузовский проспект опустел
# В Москве стало меньше роскоши
# 90
# Песков утаил место своего отпуска
# Путин сходил в горы с министром обороны и директором ФСБ
# Появились фотографии с отдыха Путина в горах
# 91
# F-35 окончательно опозорился
# Испанский истребитель случайно выпустил боевую ракету над Эстонией
# Эстонцы не смогли найти выпущенную по ошибке ракету «воздух-воздух»
# 92
# Британка восемь месяцев принимала беременность за аллергию
# Кошки почувствовали землетрясение за 10 секунд до начала и удивили интернет
# Британка узнала о беременности четвертым ребенком во время родов
# -1
# Россиян оставят без дешевых квартир
# Названы условия возвращения российских военных в Донбасс
# В Facebook нашли способ помочь всем российским детям

# %% [markdown]
# Попробуем теперь провести кластеризацию в исходном пространстве.
#
# Предварительно прикинем значение $\epsilon$ по расстоянию до ближайших соседей. Для этого используем функцию для построения графа k ближайших соседей из sklearn.

# %%
from sklearn.neighbors import kneighbors_graph
from sklearn.cluster import KMeans

# %%
# Строит разреженный граф, в котором на месте связей с ближайшими соседями стоят единицы.
wm = kneighbors_graph(w2v_vectors, 3, n_jobs=-1)

# %%
nzr, nzc = wm.nonzero()
neighbours = np.zeros(len(w2v_vectors))
for r, c in zip(nzr, nzc):
    neighbours[r] += np.linalg.norm(v1-w2v_vectors[c])
    
neighbours=sorted(neighbours/3)
fig, ax = plt.subplots()
ax.plot(range(len(neighbours)), neighbours)
plt.show()

# %% [markdown]
# Теперь проведем кластеризацию.

# %%
db=DBSCAN(eps=0.17, min_samples=3)
db_clusters=db.fit_predict(w2v_vectors)
myclr=ListedColormap(choice(list(sns.xkcd_rgb.values()), max(db_clusters)+1)) # Генерируем контрастную карту цветов.
print(max(db_clusters))
fig, ax = plt.subplots()
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], s=3, c=db_clusters, cmap=myclr)
plt.show()
# Out:
# 68

# %%
clusters=list(set(db_clusters))

for c in clusters:
    print(c)
    cntr=0
    for i, a in enumerate(news.Header):
        if db_clusters[i]==c:
            print(a)
            cntr+=1
            if cntr==3:
                break
# Out:
# 0
# «Королева дерьмовых роботов» перенесла операцию на мозге
# У Су-57 нашли «тайные ноу-хау»
# Знарок лишился еще одного поста
# 1
# Выявлен новый способ продления жизни
# Доказана эффективность вакцины против рака мозга
# Ученые обнаружили дешевый способ борьбы с раком
# 2
# На «Пикнике Афиши» выступят Земфира и Дельфин
# Выступления фестиваля Primavera Sound можно будет пережить заново
# Migos отменили выступление на фестивале Primavera
# 3
# В Москве и Петербурге покажут «Лоуренса Аравийского»
# В городах России пройдут показы спагетти-вестерна «Однажды на Диком Западе»
# Лучшие фильмы Кубрика покажут в трех городах России
# 4
# В результате извержения вулкана в Гватемале погибли люди
# Число жертв извержения вулкана в Гватемале выросло до 25
# Число жертв извержения вулкана в Гватемале превысило 60
# 5
# Актер и музыкант Тимур Миргалимов найден мертвым
# Умер актер из «Убойной силы» и «Улиц разбитых фонарей»
# Умер сыгравший Леньку в фильме «Любовь и голуби» актер
# 6
# Мальчикам разрешили ходить в школу в юбке
# Девочкам-подросткам запретили ходить в школу в юбках
# Школьнику пригрозили отчислением за стрижку
# 7
# К горбатому киту пристали полторы тысячи назойливых дельфинов
# Редкая охота десятков косаток на горбатых китов попала на видео
# Кит-убийца схватил яхту за якорь и столкнул с другим судном
# 8
# Военные кафедры при вузах отменят
# Появились подробности упразднения военных кафедр в вузах
# У россиян появится новый способ ухода от срочной службы
# 9
# Стартовали продажи новой Audi A7 Sportback
# Российским поклонникам суперкаров предложили суперчерную машину
# Новый Lexus ES приехал в Россию
# 10
# Решена проблема длинных туалетных очередей в самолете
# В аэропортах появится удобное место для сна
# Туалеты в самолетах станут еще меньше
# 11
# Самая зараженная часть Чернобыля загорелась
# На месте пожара в Чернобыле нашли факелы
# В России дадут сгореть тысячам гектаров леса в целях экономии
# 12
# Алчный отельер из Москвы решил нажиться на мексиканцах
# В московском кафе установили двойную цену для иностранцев
# Болельщиков ужаснули гостиничные номера в России
# 13
# Организаторы «Евровидения» выступили против проведения конкурса в Иерусалиме
# «Евровидение» передумали устраивать в Иерусалиме после скандала
# Победителя «Евровидения-2018» уличили в плагиате
# 14
# Кейт Миддлтон приклеила туфли к ногам
# Найден способ сходить в туалет в свадебном платье
# Кобзон попал в онкобольницу
# Раскрыты подробности «экстренной госпитализации» Кобзона
# Состояние Кобзона назвали тяжелым
# 57
# Российский лайнер почти столкнулся с другим самолетом над Черным морем
# Раскрыты подробности инцидента с российским лайнером над Черным морем
# Два лайнера едва не разбились из-за столкновения с неопознанным самолетом
# 58
# Завершился девятый этап велогонки Red Bull Trans-Siberian Extreme 2018
# Завершились очередные этапы велогонки Red Bull Trans-Siberian Extreme 2018
# Завершился заключительный этап велогонки  Red Bull Trans-Siberian Extreme 2018
# 59
# В Подмосковье нашли редкое водное растение
# В Подмосковье выросла численность лосей
# В Подмосковье обнаружили редкую хищную птицу
# 60
# СБУ задержала «шпионов» с российской символикой
# Тысячи сотрудников секретных военных баз прокололись на любви к бегу
# Военным США запретили рассекречивать базы из-за занятий спортом
# 61
# Звезда сериала «Сладкая жизнь» рассказал об оргиях в онкобольнице
# У актрисы из «Счастливы вместе» отказали сердце, легкие и почки
# Актриса из «Счастливы вместе» вышла из комы и открыла глаза
# 62
# В честь победы сборной России сделали новый iPhone
# В России выпустили антисанкционный смартфон с золотым вентилем
# В России пустили килограмм золота на смартфон
# 63
# Усманов останется без «Арсенала»
# Усманов после потери «Арсенала» замахнулся на новый клуб
# Усманов вложился в новый футбольный клуб
# 64
# «Распявший» Гагарина 34-летний художник умер в поезде
# Умер Эдуард Успенский
# Друг Эдуарда Успенского раскрыл причину его смерти
# 65
# Названы города России с лучшей и худшей экологией
# Определены самые тихие города России
# Названы самые вонючие города России
# 66
# «Калашников» представил конкурентов Tesla
# «Калашников» отказался смеяться над своим конкурентом Tesla
# Россия пристроила свой электрокар
# 67
# В Самаре выпустили гомофобный видеоролик перед выборами
# Россиян перед выборами напугали ржавой водой и «зигами»
# Актер Деревянко отказался верить в свою продажность из-за предвыборного ролика
# 68
# На российском оборонном заводе произошел взрыв
# После взрыва в здании утилизации мин погибли и пропали несколько человек
# В результате взрыва на заводе в Самаре погибли трое
# -1
# Российская легкоатлетка одержала 40 побед подряд
# В Google обнаружили «самый странный» сбой
# Британка скатилась с горы и осталась жива

# %% [markdown]
# Теперь вернемся к научным статьям.
#
# При объединении всех векторов текста происходит размытие его смысла за счет того, что некоторые понятия хоть и являются близкими, но имеют различия. Вместо того, чтобы брать само слово, давайте объединим все слова одной группы и будем брать их центроид. Заодно посмотрим какие слова попадают в одну группу.

# %%
# %%time
sci_texts['NText'] = sci_texts['Text'].map(lambda x:' '.join(normalizePymorphy(x)))
# Out:
# CPU times: user 29.1 s, sys: 63.7 ms, total: 29.2 s
# Wall time: 29.2 s

# %%
# %%time
dct = {}
# Бежим по статьям.
for article in sci_texts.NText:
    # Берем слово. Потом берем 4 соседа слева и справа.
    words = article.split(' ')
    for i, word1 in enumerate(words[4:-5]):
        for j, word2 in enumerate(words[i-4:i+4]):
            if i!=j:
                # Если основного слова еще не встречалось - добавляем его.
                if word1 not in dct.keys():
                    dct[word1] = {}
                cdict = dct[word1]
                # Говорим, что эти два слова еще раз встретились вместе.
                cdict[word2] = cdict.get(word2, 0) +1
# Out:
# CPU times: user 47.7 s, sys: 412 ms, total: 48.1 s
# Wall time: 48.1 s

# %%
# Возьмем слова, которые встречаются больше чем с 10 другими словами, каждое из которых встречается чаще 5 раз.
fd = {w:{k:np.log10(i) for k,i in dct[w].items() if i>5} for w in dct.keys() 
      if len([dct[w][k] for k in dct[w] if dct[w][k]>5])>10}

# %%
# Берем вектора слов.
sci_vects = []
sci_words = []
for word in fd.keys():
    try:
        sci_vects.append(model_w2v[word])
        sci_words.append(word)
    except Exception:
        pass

# %%
word
# Out:
# 'хромченко_NOUN'

# %%
# Посмотрим как вообще слова распределены в пространстве.
sci_map = UMAP()
sci_reduced = sci_map.fit_transform(sci_vects)

# %%
fig, ax = plt.subplots()
ax.scatter(sci_reduced[:, 0], sci_reduced[:, 1], 
           cmap=plt.cm.autumn, edgecolor='b', s=3)
plt.show()

# %%
# %%time
# Кластеризуем, в среднем по два слова на кластер.
sci_clust_no = int(len(sci_vects)/2)
km_clustering = KMeans(n_clusters=sci_clust_no)
sci_clusters = km_clustering.fit_predict(sci_vects)
# Out:
# CPU times: user 22min 14s, sys: 12min 26s, total: 34min 41s
# Wall time: 5min 51s

# %%
# Какие слова попадают в один кластер.
clust_no = 21

sci_words_sorted = sorted(zip(sci_clusters, sci_words), key= lambda x:x[0])
print([word[1] for word in sci_words_sorted if word[0]==clust_no])
# Out:
# ['седиментация_NOUN', 'оседание_NOUN', 'диагенез_NOUN', 'осадконакопление_NOUN']

# %%
# Посчитаем координаты центроидов.
cur_clust = sci_words_sorted[0][0]
cur_coord = np.array(model_w2v[sci_words_sorted[0][1]])
cur_count = 1
clust_coord = []

for i, word in enumerate(sci_words_sorted[1:]):
    if cur_clust == sci_words_sorted[i+1][0]:
        cur_coord += model_w2v[sci_words_sorted[i+1][1]]
        cur_count += 1
    else:
        clust_coord.append(cur_coord/cur_count)
        cur_clust = sci_words_sorted[i+1][0]
        cur_coord = np.array(model_w2v[sci_words_sorted[i+1][1]])
        cur_count = 1
        
clust_coord.append(cur_coord/cur_count)

# %%
# Эта функция берет центры кластеров вместо слов.
sci_set = set(sci_words)
sci_words_d = {w[1]:w[0] for w in sci_words_sorted}

def text_to_vec_centr(text):
    text_vec = np.zeros((model_w2v.vector_size,), dtype="float32")
    n_words = 0

    for word in normalizePymorphy(text):
        if word in sci_words_d.keys():
            n_words = n_words + 1
            text_vec = np.add(text_vec, clust_coord[sci_words_d[word]]) 
        else:
            try:
                text_vec = np.add(text_vec, model_w2v[word]) 
                n_words = n_words + 1
            except Exception:
                pass
    
    if n_words != 0:
        text_vec /= n_words
    return text_vec

# %%
# Строим вектора для слов.
sci_vect2 = []
for text in tqdm(sci_texts.Text):
    sci_vect2.append(text_to_vec_centr(text))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5000.0), HTML(value='')))

# %%
# Посмотрим как распределятся документы при таком подходе.
umap_sci=UMAP()
umaped_vct=umap_sci.fit_transform(sci_vect2)

# %%
fig, ax = plt.subplots()
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], edgecolor='b', s=3)
plt.show()

# %%
# Раскластеризуем документы.
db=DBSCAN(eps=0.08, min_samples=3)
db_clusters=db.fit_predict(sci_vect2)
myclr=ListedColormap(choice(list(sns.xkcd_rgb.values()), max(db_clusters)+1)) # Генерируем контрастную карту цветов.
print(max(db_clusters))
fig, ax = plt.subplots()
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], s=3, c=db_clusters, cmap=myclr)
plt.show()
# Out:
# 54

# %%
# Посмотрим на них глазами.
clusters=list(set(db_clusters))

for c in clusters:
    print('          __ ', c, ' __')
    cntr=0
    for i, a in enumerate(sci_texts.Text):
        if db_clusters[i]==c:
            print(a[:200])
            cntr+=1
            if cntr==3:
                break
# Out:
#           __  0  __
#                                                ﻿удк 641.1/.3, 641.16                технологические аспекты показателя «активность воды» и его роль в обеспечении качества продукции общественного питан
#                                                ﻿удк 641.1/.3, 641.16                технологические аспекты показателя «активность воды» и его роль в обеспечении качества продукции общественного питан
#                                                ﻿проблемы формировйния и сохранения качества жененного мармепапа                табаторович а.н.,                аспирант сибирского университета потреби
#           __  1  __
#                                                ﻿оптимизация торгового ассортимента плавленых сыров с целью удовлетворения потребительских предпочтений                н.в. данилова                в свя
#                                                ﻿оптимизация производственного ассортимента плавленых сыров на основе товарного консалтинга                н.в. данилова                сыр, благодаря ег
#                                                ﻿оптимизация торгового ассортимента плавленых сыров с целью удовлетворения потребительских предпочтений                н.в. данилова                в свя
#           __  2  __
#                                                ﻿отраслевые рынки и рыночная инфраструктура                удк 338.3.01: 338.439:336.01                формирование вертикально-интегрированных образован
#                                                ﻿отраслевые рынки и рыночная инфраструктура                удк 338.3.01: 338.439:336.01                формирование вертикально-интегрированных образован
#                                                ﻿удк 65.011.8                а.г. оловянишников                реструктуризация предприятий пищевой промышленности в отечественной и зарубежной практике
#           __  3  __
#                                                ﻿удк 664.144                ю. а. максименко, а. н. степанович, э. п. дяченко                расчет температурных полей путем реализации модели тепломасс
#                                                ﻿удк 664.144                ю. а. максименко, о. а. петровичев, р. а. максименко*                астраханский государственный технический университет зао
#                                                ﻿удк 664.144                ю. а. максименко, с. в. синяк астраханский государственный технический университет                физико-химические и теплофи
#           __  4  __
#                                                ﻿удк 664.144                л. м. титова, а. в. ревина, ю. а. максименко астраханский государственный технический университет                влияние осно
#                                                ﻿удк 664.144                ю. а. максименко                исследование кинетики процесса распылительной сушки овариальной жидкости рыб осетровы1х пород
#                                                ﻿удк 664.144                о.	а. петровичев, и. ю. алексанян астраханский государственный технический университет                исследование кинетики р
#           __  5  __
#                                                ﻿soft computing single hidden layer models for shelf life                prediction of burfi                sumit goyal, gyanendra kumar goyal, researche
#                                                ﻿linear layer and generalized regression computational intelligence models for predicting shelf life of processed cheese                sumit goyal, seni
#                                                ﻿use of silver ions in pasteurized milk production                a.v. mamaev, doctor of biological sciences k.a. leshukov, s.s. stepanova, candidates of
#           __  6  __
#                                                ﻿удк 663.479.1:005                и.в. васильева, т.а. унщикова, с.в. степанов                разработка плана насср для обеспечения безопасности
#                                                ﻿information about the authors                kosolapov vladimir mikhailovich - corresponding member of raas, doctor of agricultural sciences, director o
#                                                ﻿страницы истории тпу                удк 55(920)                жизненный путь геолога владимира ивановича брылина                в.д. евсеев, с.я. рябчи
#                                                ﻿страницы истории тпу                удк 53:37.012                о горно-геологическом образовании в томском политехническом университете на рубеже тыся
#                                                ﻿известия томского политехнического университета. 2004. т. 307. № 5                85 лет профессору с.с. сулакшину                22 ноября 2004 г. испо
#           __  23  __
#                                                ﻿геология нефти и газа                удк 550.361:553.982                взаимосвязь свойств тяжелых нефтей и уровня теплового потока на территориях волг
#                                                ﻿удк 550.361:553.982                вязкие нефти и уровень теплового потока на территориях волго-уральского, западно-сибирского и тимано-печорского бассе
#                                                ﻿удк 550.361:553.982                взаимосвязь свойств вязких нефтей и уровня теплового потока на территориях волго-уральского, западно-сибирского и тим
#           __  24  __
#                                                ﻿историческая геология                удк 56:551.73                находка ругоз и строматопороидей в лугинецкой свите верхнего девона западно-сибирской
#                                                ﻿с.а. степанов отобрал коллекцию растительных остатков франского возраста. в верхах пачки появляется прослой обломочных органогенных известняков мощность
#                                                ﻿список литературы                1.	якшин м.с. водорослевая микробиота кютингдинской свиты (нижний рифей) оленекского поднятия // геология и геофизика -
#           __  25  __
#                                                ﻿удк 553.98                роль петрофизических исследований при оценке насыщения сложнопостроенных коллекторов                б.в. белозеров
#                                                ﻿список литературы                1.	гурова т.и., казаринов в.п. литология и палеогеография западно-сибирской низменности в связи с нефтегазоносностью. -
#                                                ﻿проблемы структурной геометризации продуктивных пластов месторождений углеводородов                а.п. хаустов                экологический факультет р
#           __  26  __
#                                                ﻿страницы истории тпу                удк 929                профессор иннокентий александрович молчанов - к 120-летию со дня рождения                а.ф.
#                                                ﻿страницы истории тпу                удк 553(09)                125 лет со дня рождения профессора б.л. степанова -организатора первой кафедры в сибири д
#                                                ﻿страницы истории тпу                удк 553(09)                полевые маршруты геолога александра ивановича иванова                а.я. пшеничкин
#           __  27  __
#                                                ﻿т ,                „л-: ■ _                взятии производных можно поставить х=г и у=0. можно также ограничиться рассмотрением только первой, самой мощ
#                                                ﻿удк 624.131.1 (571.5)                геолого-генетические комплексы дисперсных грунтов монголии (на примере территории г. эрдэнэт)                т.г.ря
#                                                ﻿удк 624.131.1 (571.5)                методы изучения микроструктуры дисперсных грунтов                т.г.рященко1, ю.в.чернышова2                инстит
#           __  28  __
#                                                ﻿геомеханика                удк 622.833.3                с. п. бахаева, м.а.кузнецов , е.в. костюков                геомеханические проблемы открытых гор
#                                                ﻿удк 662                в. п. жариков, в. в. ермошкин, р. г. клейменов                рациональное землепользование при формировании отвалов и гидроотвал
#                                                ﻿удк 622.271.452:624.131.537                е.н.заворина, а.н.куксов                особенности внешнего отвалообразования для условий ерунаковского геол
#           __  29  __
#                                                ﻿из таблицы видно, что сокращение узлов нерегулярной сетки з&#34,2 (и используемой памяти компьютера) происходит в 3-6 раз, количество итераций метода со
#                                                ﻿удк 622.831                геоинформационная модель геомеханического состояния жильных золоторудных месторождений на основе выявления и использования ди
#                                                ﻿методические подходы к исследованию геомеханических процессов при разработке месторождений углеводородов шельфа баренцева моря                а.и. калаш
#                                                ﻿горно-электромеханический факультет ( путь длиною в 58 лет )                история горно-электромеханического факультета началась с электромеханическог
#                                                ﻿навстречу 60-летию кузгту                инженерно-экономический факультет                в г. кемерово на улице дзержинского привлекает внимание красив
#           __  39  __
#                                                ﻿удк 539.3                осесимметричная задача о распределении напряжений                на упруго закрепленной границе изотропного полупространства пр
#                                                ﻿удк 530                применение метода граничных интегральных уравнении к решению плоских задач теории упругости с подвижной нагрузкой
#                                                ﻿удк 530                применение метода граничных интегральных уравнений к решению связанных задач термоупругости c подвижной нагрузкой
#           __  40  __
#                                                ﻿удк 539.3                контактная задача для двойного слоя с учетом сил трения                © 2005 г. м.и. чебаков                the spatial contac
#                                                ﻿удк 539.3                асимптотическим метод расчета двухслойного сферического подшипника скольжения                © 2008 г. м.и. чебаков1, п.г. иван
#                                                ﻿изменяя далее значения коэффициента турбулентной диффузии при постоянных значениях скорости ветра и расстояния до точки наблюдения, видим, что с усилени
#           __  41  __
#                                                ﻿удк 621.89                к решению контактной задачи термоупругости применительно к зубчатой передаче                г. п. тариков                учреж
#                                                ﻿механика                удк 539.3                об ударе параболического штампа в упругую полуплоскость                © 2011 г. в.б. зеленцов
#                                                ﻿удк 539.3                об одном методе решения нестационарных динамических контактных задач теории упругости об ударе                © 2010 г. в.б. зе
#           __  42  __
#                                                ﻿удк 539.3                некоторые задачи статики упругих тел при учете                межфазных границ                © 2007 г в.а. еремеев, с.м. кузьм
#                                                ﻿удк 539.3                о термодинамическом равновесии фаз двухкомпонентных линейно-упругих сред                © 2004 г. в.а. еремеев, с.м. кузьменко
#                                                ﻿величина а является конкретным значением для исследуемой скважины и определяется путем обработки зависимости, полученной в результате промысловых исслед
#           __  43  __
#                                                ﻿удк 539.3                с.м. шляхов, э.ф. кривулина                задача термоупругости для круглой плиты                из пористого материала в одно
#                                                ﻿удк 5з9.з                с.м. шляхов, а.в. ефремов                задача теплопроводности и термоупругости круглой пористой пластины в нестационарном ре
#                                                ﻿удк 536.2                исследование стационарной теплопроводности в телах вращения из слоистых композитов                г.м. куликов, и.е. карева
#           __  44  __
#                                                ﻿ния исследования у детей экспериментальной группы мотивация существенно изменилась.                2. результаты контрольно-переводных тестов еще раз по
#                                                ﻿ния исследования у детей экспериментальной группы мотивация существенно изменилась.                2. результаты контрольно-переводных тестов еще раз по
#                                                ﻿и скоростно-силовые (0,743) качества. второй фактор, вклад которого в обобщенную дисперсию выборки составил 19,9%. в него вошли показатели физического р
#           __  45  __
#                                                ﻿б. а. столяров,                доктор педагогических наук, профессор кафедры художественного образования и музейной педагогики, заведующий отделом «росс
#                                                ﻿б. а. столяров,                доктор педагогических наук, профессор кафедры художественного образования и музейной педагогики, заведующий отделом «росс
#                                                ﻿1979. с. 7, минский, м, остроумие и логика когнитивного бессознательного [текст] / м. минский // новое в зарубежной лингвистике. м.: прогресс, 1988. вып
#           __  46  __
#                                                ﻿а. с. роботова,                профессор кафедры педагогики                е. в. капустина,                учитель гимназии № 441 санкт-петербурга
#                                                ﻿физические процессы, происходящие при хранении продовольственных товаров                г.я. резго, м.а. николаева                все процессы, происход
#                                                ﻿слабоалкогольные тонизирующие напитки: состав, регламентируемый нормативным документом гост р 52845-2007                ю.в. кокина                питан
#                                                ﻿влияние компонентного состава переработанных сыров на формирование производственного ассортимента                н.в. данилова                проблема п

# %% [markdown]
# А теперь поступим по-другому. Разделим слова на 50 кластеров, а в качестве вектора признаков документа будем брать число слов данного документа, попадающих в каждый кластер.

# %%
# %%time
cluster_space_size = 50
km_clustering = KMeans(n_clusters=cluster_space_size)
sci_clusters = km_clustering.fit_predict(sci_vects)
# Out:
# CPU times: user 46.1 s, sys: 33.5 s, total: 1min 19s
# Wall time: 14.4 s

# %%
# Эта функция берет для документа количество слов по кластерам..
sci_set = set(sci_words)
sci_words_d = {w[1]:w[0] for w in sci_words_sorted}

def text_to_centoids(text):
    text_vec = np.zeros((cluster_space_size,), dtype="float32")
    n_words = 0

    for sent in normalizePymorphy(text):
        for word in sent:
            if word in sci_words_d.keys():
                n_words = n_words + 1
                text_vec[clust_coord[sci_words_d[word]]] += 1
    
    if np.sum(text_vec) != 0:
        text_vec /= np.sum(text_vec)
    return text_vec

# %%
clust_coord[sci_words_d['процесс_NOUN']]
# Out:
# array([ 4.04470e-02, -3.98800e-03,  1.11400e-03, -1.56500e-03,
#         6.45370e-02, -7.96240e-02,  4.66350e-02, -3.29250e-02,
#        -1.41430e-02,  8.69380e-02, -4.67300e-03, -5.26580e-02,
#         1.37880e-02, -2.86750e-02, -5.35310e-02, -5.29950e-02,
#         1.44490e-02, -7.23880e-02, -1.25670e-02, -5.48660e-02,
#         5.29610e-02, -1.05060e-02,  2.49140e-02, -9.88500e-03,
#        -1.52450e-02,  4.15680e-02,  5.18310e-02,  3.45090e-02,
#        -7.86200e-03, -6.38200e-03, -8.40150e-02,  4.57990e-02,
#        -2.89400e-03, -4.24810e-02,  1.44500e-02, -8.44400e-03,
#        -9.77600e-03, -8.53950e-02, -1.62200e-02, -9.32930e-02,
#         6.92100e-02, -1.57870e-02, -8.50000e-02, -3.09930e-02,
#        -3.46800e-02, -7.84510e-02,  4.50060e-02, -2.52400e-02,
#         8.62420e-02,  3.34210e-02,  5.05370e-02, -1.82630e-02,
#        -7.30700e-03, -1.26520e-02, -2.34500e-03, -4.64850e-02,
#         1.27570e-02,  2.96980e-02,  6.03150e-02, -1.21400e-02,
#        -7.64200e-03, -9.79990e-02,  3.94980e-02, -2.06000e-02,
#        -1.82730e-02,  3.28910e-02, -5.45530e-02,  2.02760e-02,
#         3.28580e-02, -2.04910e-02,  5.81340e-02,  1.96048e-01,
#        -5.15260e-02,  1.99910e-02,  6.20540e-02, -6.27240e-02,
#         9.42100e-02, -9.21430e-02,  6.70300e-02,  2.16380e-02,
#         9.66700e-02,  1.34688e-01,  7.93300e-02, -1.09519e-01,
#         1.73780e-02,  3.33500e-02, -8.98150e-02,  3.52860e-02,
#         4.80030e-02,  3.20800e-02, -6.21390e-02, -4.41380e-02,
#         5.66000e-04, -5.50720e-02,  5.75800e-03,  1.93880e-02,
#        -5.29010e-02, -2.53740e-02, -4.52330e-02,  7.77730e-02,
#        -1.80680e-02,  2.08690e-02,  2.74690e-02, -1.09872e-01,
#        -1.40336e-01, -7.50760e-02, -4.95870e-02, -2.78040e-02,
#        -3.50100e-02, -6.48450e-02, -2.13940e-02, -4.57820e-02,
#         8.98840e-02, -3.90330e-02, -3.67850e-02,  9.99700e-03,
#        -1.20420e-02, -3.60500e-03, -7.39800e-02, -8.36500e-03,
#        -6.35000e-03,  5.01270e-02,  3.52820e-02,  8.65760e-02,
#         4.99260e-02, -6.54560e-02,  4.66340e-02,  9.38880e-02,
#        -1.77200e-03, -4.45270e-02,  5.57380e-02,  9.82000e-04,
#        -6.43890e-02, -1.58810e-02, -1.05026e-01, -8.04380e-02,
#        -6.19670e-02, -3.20040e-02,  5.21760e-02, -1.15354e-01],
#       dtype=float32)

# %%
# Эта функция берет для документа количество слов по кластерам..
sci_set = set(sci_words)
sci_words_d = {w[1]:w[0] for w in sorted(zip(sci_clusters, sci_words), key= lambda x:x[0])}

def text_to_centoids(text):
    text_vec = np.zeros((cluster_space_size,), dtype="float32")
    n_words = 0

    for word in text.split():
        if word in sci_words_d.keys():
            text_vec[sci_words_d[word]] += 1
    
    if np.sum(text_vec) != 0:
        text_vec /= np.sum(text_vec)
    return text_vec

# %%
# Строим вектора для слов.
sci_vect3 = []
for text in tqdm(sci_texts.NText):
    sci_vect3.append(text_to_centoids(text))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5000.0), HTML(value='')))

# %%
# Посмотрим как распределятся документы при таком подходе.
umap_sci=UMAP()
umaped_vct=umap_sci.fit_transform(sci_vect3)

fig, ax = plt.subplots()
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], edgecolor='b', s=3)
plt.show()

# %%
# Раскластеризуем документы.
db=DBSCAN(eps=0.075, min_samples=3)
db_clusters=db.fit_predict(sci_vect3)
myclr=ListedColormap(choice(list(sns.xkcd_rgb.values()), max(db_clusters)+1)) # Генерируем контрастную карту цветов.
print(max(db_clusters))
fig, ax = plt.subplots()
ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], s=3, c=db_clusters, cmap=myclr)
plt.show()

# %%
# Посмотрим на них глазами.
clusters=list(set(db_clusters))

for c in clusters:
    print(f'__ {c} __')
    cntr=0
    for i, a in enumerate(sci_texts.Text):
        if db_clusters[i]==c:
            print(a[:200])
            cntr+=1
            if cntr==3:
                break

# %%
X_train, X_test, y_train, y_test = train_test_split(sci_vect3, classes, test_size=0.2, random_state=333)
tree = RandomForestClassifier(criterion='entropy', random_state=333)
tree.fit(X_train, y_train)
y_hat=tree.predict(X_test)
print(len([1 for i, j in zip(y_hat, y_test) if i==j])/len(y_test))
confusion_matrix(y_test, y_hat)

# %% [markdown]
# -----

# %% [markdown]
# А теперь посмотрим на FastText.

# %%
from gensim.models.fasttext import FastText

# %%
#model_ft = KeyedVectors.load_fasttext_format('data/araneum_none_fasttextskipgram_300_5_2018.tgz', binary=True)

#model_ft = FastText.load('data/araneum_none_fasttextskipgram_300_5_2018.tgz')

# %%
tmp_dict2 = {} # Кеш значимых слов.

morph = pymorphy2.MorphAnalyzer()

# Фильтруем по части речи и возвращаем только начальную форму.
def normalizePymorphy3(text):
    output = []
    # Делим на предложения самым страшным из возможных образов.
    sentences = text.split('.')
    for sentence in sentences:
        tokens = re.findall('[A-Za-zА-Яа-яЁё]+\-[A-Za-zА-Яа-яЁё]+|[A-Za-zА-Яа-яЁё]+', sentence)
        # Берем предложения не менее чем из 5 слов.
        if len(tokens)<=4:
            continue
        words = []
        for t in tokens:
            # Если токен уже был закеширован, быстро возьмем результат из него.
            if t in tmp_dict2.keys():
                words.append(tmp_dict2[t])
            # Слово еще не встретилось, будем проводить медленный морфологический анализ.
            else:
                pv = morph.parse(t)
                if pv[0].tag.POS != None:
                    # Отправляем слово в результат, ...
                    words.append(pv[0].normal_form)
                    # ... и кешируем результат его разбора.
                    tmp_dict2[t] = pv[0].normal_form
        output.append(words)
                    
    return output

# %%
all_sentences = []
for text in tqdm(news.News):
    all_sentences.extend(normalizePymorphy3(text))

# %%
# %%time
# список параметров, которые можно менять по вашему желанию
num_features = 300  # итоговая размерность вектора каждого слова
min_word_count = 5  # минимальная частотность слова, чтобы оно попало в модель
num_workers = 3     # количество ядер вашего процессора, чтоб запустить обучение в несколько потоков
context = 10        # размер окна 
downsampling = 1e-3 # внутренняя метрика модели


model_ft = FastText(all_sentences, workers=num_workers, size=num_features,
                 min_count=min_word_count, window=context, sample=downsampling)

# %%
model_ft.init_sims(replace=True)

# %%
model_ft.save("data/fast_text_news.bin")

# %%
model_ft = FastText.load("data/fast_text_news.bin")
#model_ft = FastText.load('data/araneum_none_fasttextskipgram_300_5_2018.tgz')
# Мне не хватило 16 Гб оперативной памяти, чтобы загрузить эту модель.
#model_ft = FastText.load_fasttext_format("data/cc.ru.300.bin.gz")

# %%
model_ft.wv['король_']-model_ft.wv['мужчина_']+model_ft.wv['женщина_']- model_ft.wv['королева_']

# %%
from gensim.models import KeyedVectors # Семантические вектора.

# %%
#model_ft.wv.most_similar(positive=[u'пожар'])
#model_ft.wv.most_similar(positive=[u'пожар'], negative=[u'пламя'])
#model_ft.wv.most_similar(positive=[u'топливо_'], negative=[u'нефть_'])
#model_w2v.most_similar(positive=[u'женщина_NOUN', u'император_NOUN' ], negative=[u'мужчина_NOUN'])
#model_ft.most_similar(positive=[u'король_NOUN', u'женщина_NOUN'], negative=[u'мужчина_NOUN'])
#model_ft.most_similar(positive=[u'король_', u'женщина_'], negative=[u'мужчина_'])
#model_ft.most_similar(positive=[u'король', u'женщина'], negative=[u'мужчина'])
#model_ft.most_similar(positive=[u'президент', u'женщина'], negative=[u'мужчина'])
#model_ft.most_similar(negative=[u'король', u'мужчина'], positive=[u'женщина'])
#model_ft.most_similar(positive=[u'женщина_', u'король_'])
#model_ft.most_similar(positive=['германия_', 'москва_' ], negative=['берлин_'])
print(model_ft.wv.most_similar(positive=[u'король_', u'женщина_'], negative=[u'мужчина_']), "\n\n",
model_ft.wv.most_similar([model_ft.wv['король_']-model_ft.wv['мужчина_']+model_ft.wv['женщина_']]))

# %% [markdown]
# ### Что осталось за кадром?
#
# - BERT | ELMO (+ DeepPavlov)
# - Онтологии.
# - graph2vec (последовательность прослушанных песен, просмотр товаров, ...).
